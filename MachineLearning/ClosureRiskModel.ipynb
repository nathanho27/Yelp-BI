# %% [markdown]
# # Closure Risk Proxy Model
# =================================
# # Goal: To estimate relative business closure risk using observable Yelp signals.
#
# This notebook develops a closure risk proxy model for the Yelp-BI project.
# The objective is to estimate relative business fragility based on observable
# Yelp signals such as customer engagement, momentum, performance relative to
# expected rating, and competitive environment.
#
# Because true closure outcomes are not consistently available through the Yelp
# Fusion API, this model does not perform binary classification. Instead, it
# produces an interpretable risk score and risk buckets that identify businesses
# that appear more or less vulnerable relative to peers.
#
# Before constructing the risk proxy, we perform data validation and exploratory
# analysis to confirm that the selected signals are meaningfully associated with
# business risk characteristics.

# %% [markdown]
# # Imports and Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
df = pd.read_csv("/Users/nathanho/Desktop/Yelp-BI/data/clean/austin_clean.csv")

# %%
df.shape
df.head()
# Out:
#               business_id                         name    city state  \
# 0  cs6HfZNykLVitm09jWFqWg              Moonshine Grill  Austin    TX
# 1  He2KYtXXfaIR0nkCXH5xiQ  Loro Asian Smokehouse & Bar  Austin    TX
# 2  Rba9Ol4jnTiov6_iAuoF5g            1618 Asian Fusion  Austin    TX
# 3  BHZ9puL8YuHE-YEdkmxH-g                        Canje  Austin    TX
# 4  YZs1gNSh_sN8JmN_nrpxeA       Terry Black's Barbecue  Austin    TX
#
#                                     address  postal_code  rating  \
# 0        303 Red River St, Austin, TX 78701        78701     4.4
# 1       2115 S Lamar Blvd, Austin, TX 78704        78704     4.3
# 2     1618 E Riverside Dr, Austin, TX 78741        78741     4.7
# 3    1914 E 6th St, Ste C, Austin, TX 78702        78702     4.5
# 4  1003 Barton Springs Rd, Austin, TX 78704        78704     4.5
#
#    review_count price  price_level is_closed  \
# 0          6314    $$          2.0         f
# 1          2497    $$          2.0         f
# ...
